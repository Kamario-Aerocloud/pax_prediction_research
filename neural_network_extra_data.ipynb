# %%
import tensorflow as tf
print(tf.__version__)

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Dropout, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
# Out:
# 2.19.0

# %%
columns = [
    'Boarded', 'actual_date', 'Destination Airport_encoded', 'Airline_encoded',
    'Day_of_Week', 'Month', 'Day_of_Month', 'day_sin',  'month_sin', 'dow_sin',
    'day_cos', 'month_cos', 'dow_cos', 'route_mean', 'route_median', 'route_std',
     'max_seats'
]

df = pd.read_csv('Datasets/SRQ_flights.csv', usecols=columns)
df['actual_date'] = pd.to_datetime(df['actual_date']).dt.tz_localize(None)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14016 entries, 0 to 14015
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Boarded                      14016 non-null  int64
#  1   Day_of_Week                  14016 non-null  int64
#  2   Month                        14016 non-null  int64
#  3   Day_of_Month                 14016 non-null  int64
#  4   Destination Airport_encoded  14016 non-null  int64
#  5   Airline_encoded              14016 non-null  int64
#  6   day_sin                      14016 non-null  float64
#  7   day_cos                      14016 non-null  float64
#  8   month_sin                    14016 non-null  float64
#  9   month_cos                    14016 non-null  float64
#  10  dow_sin                      14016 non-null  float64
#  11  dow_cos                      14016 non-null  float64
#  12  route_mean                   14016 non-null  float64
#  13  route_median                 14016 non-null  float64
#  14  route_std                    14004 non-null  float64
#  15  max_seats                    14016 non-null  float64
#  16  actual_date                  13603 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(10), int64(6)
# memory usage: 1.8 MB

# %%
#Extract time of day in seconds
df['seconds_in_day'] = (
    df['actual_date'].dt.hour * 3600 +
    df['actual_date'].dt.minute * 60 +
    df['actual_date'].dt.second
)

# Normalize to [0, 2π]
seconds_in_day_total = 24 * 60 * 60  # 86400
df['time_angle'] = 2 * np.pi * df['seconds_in_day'] / seconds_in_day_total

# Compute sin and cos
df['time_sin'] = np.sin(df['time_angle'])
df['time_cos'] = np.cos(df['time_angle'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14016 entries, 0 to 14015
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Boarded                      14016 non-null  int64
#  1   Day_of_Week                  14016 non-null  int64
#  2   Month                        14016 non-null  int64
#  3   Day_of_Month                 14016 non-null  int64
#  4   Destination Airport_encoded  14016 non-null  int64
#  5   Airline_encoded              14016 non-null  int64
#  6   day_sin                      14016 non-null  float64
#  7   day_cos                      14016 non-null  float64
#  8   month_sin                    14016 non-null  float64
#  9   month_cos                    14016 non-null  float64
#  10  dow_sin                      14016 non-null  float64
#  11  dow_cos                      14016 non-null  float64
#  12  route_mean                   14016 non-null  float64
#  13  route_median                 14016 non-null  float64
#  14  route_std                    14004 non-null  float64
#  15  max_seats                    14016 non-null  float64
#  16  actual_date                  13603 non-null  datetime64[ns]
#  17  seconds_in_day               13603 non-null  float64
#  18  time_angle                   13603 non-null  float64
#  19  time_sin                     13603 non-null  float64
#  20  time_cos                     13603 non-null  float64
# dtypes: datetime64[ns](1), float64(14), int64(6)
# memory usage: 2.2 MB

# %%
feature_columns = [  'Destination Airport_encoded', 'Airline_encoded',
    #'Day_of_Week', 'Month', 'Day_of_Month', 
    'day_sin',  'month_sin', 'dow_sin',
    'day_cos', 'month_cos', 'dow_cos', 
    'route_mean', 'route_median', 'route_std', 'time_sin', 'time_cos', 'max_seats']

# %%
X = df[feature_columns]
y = df['Boarded']  # or whatever your target column is
dates = df['actual_date']


split_index = int(len(df) * 0.8)

# Split data chronologically
X_train = X.iloc[:split_index]
X_test = X.iloc[split_index:]
#X_test = X_train

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]
#y_test = y_train

dates_train = dates.iloc[:split_index]
dates_test = dates.iloc[split_index:]

print(f"Training set size: {X_train.shape[0]}")
print(f"Testing set size: {X_test.shape[0]}")
print(f"Training target range: {y_train.min()} to {y_train.max()}")
print(f"Testing target range: {y_test.min()} to {y_test.max()}")
# Out:
# Training set size: 11212
# Testing set size: 2804
# Training target range: 10 to 249
# Testing target range: 10 to 238

# %%
# Get the split index (number of training samples)
split_index = len(y_train)

# Extract date and passenger count
df_timestamps = df['actual_date']
passenger_counts = df['Boarded']

# Plot
plt.figure(figsize=(20, 8))

plt.plot(df_timestamps[:split_index], passenger_counts[:split_index], label='Train', color='blue')
plt.plot(df_timestamps[split_index:], passenger_counts[split_index:], label='Test', color='orange')

plt.title('Passenger Count Over Time (Train/Test Split)', fontsize=16)
plt.xlabel('Flight Date', fontsize=14)
plt.ylabel('Passenger Count', fontsize=14)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
 
# Define scheduler function
def scheduler(epoch, lr):
    if epoch%10 != 0:
        return lr
    else:
        return lr * 0.925  # decay by 10%
 
lr_callback = LearningRateScheduler(scheduler)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(14,)),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear'),    
])

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae', 'mse']
             )

model.summary()
# Out:
# C:\Users\KamarioSinclair\.conda\envs\pax-prediction\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 1024)           │        15,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,452,481 (24.61 MB)
#  Trainable params: 6,452,481 (24.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# For validation during training, use chronological split within training data
# Take last 20% of training data as validation set
val_split_index = int(len(X_train) * 0.8)

X_train_final = X_train[:val_split_index]
X_val = X_train[val_split_index:]
y_train_final = y_train.iloc[:val_split_index]
y_val = y_train.iloc[val_split_index:]

print("NaNs in X_val:", np.isnan(X_val).sum())
print("NaNs in y_val:", np.isnan(y_val).sum())

# Check for infinities
print("Infs in X_val:", np.isinf(X_val).sum())
print("Infs in y_val:", np.isinf(y_val).sum())
# Out:
# NaNs in X_val: Destination Airport_encoded     0
# Airline_encoded                 0
# day_sin                         0
# month_sin                       0
# dow_sin                         0
# day_cos                         0
# month_cos                       0
# dow_cos                         0
# route_mean                      0
# route_median                    0
# route_std                       4
# time_sin                       10
# time_cos                       10
# max_seats                       0
# dtype: int64
# NaNs in y_val: 0
# Infs in X_val: Destination Airport_encoded    0
# Airline_encoded                0
# day_sin                        0
# month_sin                      0
# dow_sin                        0
# day_cos                        0
# month_cos                      0
# dow_cos                        0
# route_mean                     0
# route_median                   0
# route_std                      0
# time_sin                       0
# time_cos                       0
# max_seats                      0
# dtype: int64
# Infs in y_val: 0

# %%
history = model.fit(X_train_final, y_train_final,
                    epochs=200,
                    batch_size=128,
                    validation_data=(X_val, y_val),  # or use x_test/y_test for validation if you prefer
                    verbose=1,
                    callbacks=[lr_callback])
# Out:
# Epoch 1/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 4477.6602 - mae: 52.4593 - mse: 4477.6602 - val_loss: 1952.0480 - val_mae: 36.8137 - val_mse: 1952.0480 - learning_rate: 9.2500e-04
# Epoch 2/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2065.6038 - mae: 37.7690 - mse: 2065.6038 - val_loss: 1895.9722 - val_mae: 36.1292 - val_mse: 1895.9722 - learning_rate: 9.2500e-04
# Epoch 3/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2014.6940 - mae: 37.3705 - mse: 2014.6940 - val_loss: 1949.8386 - val_mae: 36.7874 - val_mse: 1949.8386 - learning_rate: 9.2500e-04
# Epoch 4/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2027.9790 - mae: 37.4638 - mse: 2027.9790 - val_loss: 1719.8600 - val_mae: 33.6322 - val_mse: 1719.8600 - learning_rate: 9.2500e-04
# Epoch 5/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2022.2087 - mae: 37.4126 - mse: 2022.2087 - val_loss: 1772.1245 - val_mae: 33.6673 - val_mse: 1772.1245 - learning_rate: 9.2500e-04
# Epoch 6/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2083.6333 - mae: 37.8673 - mse: 2083.6333 - val_loss: 2075.0896 - val_mae: 38.2270 - val_mse: 2075.0896 - learning_rate: 9.2500e-04
# Epoch 7/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2066.4463 - mae: 37.8270 - mse: 2066.4463 - val_loss: 1731.9934 - val_mae: 33.4964 - val_mse: 1731.9934 - learning_rate: 9.2500e-04
# Epoch 8/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - loss: 2069.9941 - mae: 37.8707 - mse: 2069.9941 - val_loss: 1720.4135 - val_mae: 33.6471 - val_mse: 1720.4135 - learning_rate: 9.2500e-04
# Epoch 9/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 98ms/step - loss: 2036.4254 - mae: 37.4717 - mse: 2036.4254 - val_loss: 1827.5756 - val_mae: 35.2582 - val_mse: 1827.5756 - learning_rate: 9.2500e-04
# Epoch 10/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 2087.5916 - mae: 37.8960 - mse: 2087.5916 - val_loss: 1922.8362 - val_mae: 36.4614 - val_mse: 1922.8362 - learning_rate: 9.2500e-04
# Epoch 11/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2013.9933 - mae: 37.3497 - mse: 2013.9933 - val_loss: 1765.0697 - val_mae: 34.4147 - val_mse: 1765.0697 - learning_rate: 8.5563e-04
# Epoch 12/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2012.5343 - mae: 37.3362 - mse: 2012.5343 - val_loss: 1770.8828 - val_mae: 34.4988 - val_mse: 1770.8828 - learning_rate: 8.5563e-04
# Epoch 13/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2056.1794 - mae: 37.7402 - mse: 2056.1794 - val_loss: 1727.7477 - val_mae: 33.8201 - val_mse: 1727.7477 - learning_rate: 8.5563e-04
# Epoch 14/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2054.3838 - mae: 37.7411 - mse: 2054.3838 - val_loss: 1920.9750 - val_mae: 34.5175 - val_mse: 1920.9750 - learning_rate: 8.5563e-04
# Epoch 15/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2046.5551 - mae: 37.5572 - mse: 2046.5551 - val_loss: 1758.3198 - val_mae: 33.6002 - val_mse: 1758.3198 - learning_rate: 8.5563e-04
# Epoch 16/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 2105.4453 - mae: 38.0756 - mse: 2105.4453 - val_loss: 1944.0094 - val_mae: 36.7174 - val_mse: 1944.0094 - learning_rate: 8.5563e-04
# Epoch 17/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 2013.5652 - mae: 37.3531 - mse: 2013.5652 - val_loss: 1854.0166 - val_mae: 35.5943 - val_mse: 1854.0166 - learning_rate: 8.5563e-04
# Epoch 18/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2014.6389 - mae: 37.3895 - mse: 2014.6389 - val_loss: 1809.1244 - val_mae: 35.0209 - val_mse: 1809.1244 - learning_rate: 8.5563e-04
# Epoch 19/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2041.6580 - mae: 37.5512 - mse: 2041.6580 - val_loss: 1813.6658 - val_mae: 35.0792 - val_mse: 1813.6658 - learning_rate: 8.5563e-04
# Epoch 20/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 
200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2000.5098 - mae: 37.2080 - mse: 2000.5098 - val_loss: 1772.8563 - val_mae: 34.5263 - val_mse: 1772.8563 - learning_rate: 5.3596e-04
# Epoch 72/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2027.1223 - mae: 37.4738 - mse: 2027.1223 - val_loss: 1803.8280 - val_mae: 34.9517 - val_mse: 1803.8280 - learning_rate: 5.3596e-04
# Epoch 73/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2028.3153 - mae: 37.4985 - mse: 2028.3153 - val_loss: 1808.2899 - val_mae: 35.0101 - val_mse: 1808.2899 - learning_rate: 5.3596e-04
# Epoch 74/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 2012.4922 - mae: 37.2898 - mse: 2012.4922 - val_loss: 1777.8217 - val_mae: 34.5934 - val_mse: 1777.8217 - learning_rate: 5.3596e-04
# Epoch 75/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2004.9103 - mae: 37.2760 - mse: 2004.9103 - val_loss: 1741.5786 - val_mae: 34.0640 - val_mse: 1741.5786 - learning_rate: 5.3596e-04
# Epoch 76/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2004.9506 - mae: 37.2992 - mse: 2004.9506 - val_loss: 1773.4036 - val_mae: 34.5338 - val_mse: 1773.4036 - learning_rate: 5.3596e-04
# Epoch 77/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 1998.5521 - mae: 37.2100 - mse: 1998.5521 - val_loss: 1785.8834 - val_mae: 34.7085 - val_mse: 1785.8834 - learning_rate: 5.3596e-04
# Epoch 78/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 1999.1937 - mae: 37.2318 - mse: 1999.1937 - val_loss: 1718.8868 - val_mae: 33.5019 - val_mse: 1718.8868 - learning_rate: 5.3596e-04
# Epoch 79/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 2017.1849 - mae: 37.2851 - mse: 2017.1849 - val_loss: 1740.7922 - val_mae: 34.0509 - val_mse: 1740.7922 - learning_rate: 5.3596e-04
# Epoch 80/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2008.0767 - mae: 37.2740 - mse: 2008.0767 - val_loss: 1931.9917 - val_mae: 36.5719 - val_mse: 1931.9917 - learning_rate: 5.3596e-04
# Epoch 81/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2014.0947 - mae: 37.3950 - mse: 2014.0947 - val_loss: 1786.9769 - val_mae: 34.7237 - val_mse: 1786.9771 - learning_rate: 4.9576e-04
# Epoch 82/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - loss: 2007.3014 - mae: 37.3033 - mse: 2007.3014 - val_loss: 1858.2656 - val_mae: 35.6489 - val_mse: 1858.2656 - learning_rate: 4.9576e-04
# Epoch 83/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - loss: 2012.8295 - mae: 37.4295 - mse: 2012.8295 - val_loss: 1797.6614 - val_mae: 34.8685 - val_mse: 1797.6614 - learning_rate: 4.9576e-04
# Epoch 84/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - loss: 2003.0112 - mae: 37.2521 - mse: 2003.0112 - val_loss: 1815.9102 - val_mae: 35.1089 - val_mse: 1815.9102 - learning_rate: 4.9576e-04
# Epoch 85/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 2008.5747 - mae: 37.3252 - mse: 2008.5747 - val_loss: 1817.0746 - val_mae: 35.1242 - val_mse: 1817.0746 - learning_rate: 4.9576e-04
# Epoch 86/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2009.3495 - mae: 37.2828 - mse: 2009.3495 - val_loss: 1717.9844 - val_mae: 33.5533 - val_mse: 1717.9844 - learning_rate: 4.9576e-04
# Epoch 87/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2026.9260 - mae: 37.4357 - mse: 2026.9260 - val_loss: 1723.6282 - val_mae: 33.4825 - val_mse: 1723.6282 - learning_rate: 4.9576e-04
# Epoch 88/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 
200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2010.8322 - mae: 37.2610 - mse: 2010.8322 - val_loss: 1838.5455 - val_mae: 35.3979 - val_mse: 1838.5455 - learning_rate: 4.2419e-04
# Epoch 107/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 2003.5396 - mae: 37.2931 - mse: 2003.5396 - val_loss: 1717.9158 - val_mae: 33.5357 - val_mse: 1717.9158 - learning_rate: 4.2419e-04
# Epoch 108/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 2021.4843 - mae: 37.3795 - mse: 2021.4843 - val_loss: 1821.0516 - val_mae: 35.1758 - val_mse: 1821.0516 - learning_rate: 4.2419e-04
# Epoch 109/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2010.0729 - mae: 37.3188 - mse: 2010.0729 - val_loss: 1769.3632 - val_mae: 34.4773 - val_mse: 1769.3632 - learning_rate: 4.2419e-04
# Epoch 110/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2007.2267 - mae: 37.2771 - mse: 2007.2267 - val_loss: 1838.9205 - val_mae: 35.4028 - val_mse: 1838.9205 - learning_rate: 4.2419e-04
# Epoch 111/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 2000.4803 - mae: 37.2554 - mse: 2000.4803 - val_loss: 1907.7942 - val_mae: 36.2745 - val_mse: 1907.7942 - learning_rate: 3.9237e-04
# Epoch 112/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2015.9982 - mae: 37.3872 - mse: 2015.9982 - val_loss: 1718.5494 - val_mae: 33.5076 - val_mse: 1718.5494 - learning_rate: 3.9237e-04
# Epoch 113/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2021.3959 - mae: 37.3403 - mse: 2021.3959 - val_loss: 1891.9690 - val_mae: 36.0791 - val_mse: 1891.9690 - learning_rate: 3.9237e-04
# Epoch 114/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2003.9585 - mae: 37.2721 - mse: 2003.9585 - val_loss: 1752.2532 - val_mae: 34.2268 - val_mse: 1752.2532 - learning_rate: 3.9237e-04
# Epoch 115/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2003.1676 - mae: 37.2514 - mse: 2003.1676 - val_loss: 1754.8181 - val_mae: 34.2664 - val_mse: 1754.8181 - learning_rate: 3.9237e-04
# Epoch 116/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2013.4296 - mae: 37.3381 - mse: 2013.4296 - val_loss: 1761.3179 - val_mae: 34.3609 - val_mse: 1761.3179 - learning_rate: 3.9237e-04
# Epoch 117/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2012.4332 - mae: 37.3201 - mse: 2012.4332 - val_loss: 1725.9648 - val_mae: 33.7806 - val_mse: 1725.9648 - learning_rate: 3.9237e-04
# Epoch 118/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1997.9895 - mae: 37.2189 - mse: 1997.9895 - val_loss: 1737.1606 - val_mae: 33.9932 - val_mse: 1737.1606 - learning_rate: 3.9237e-04
# Epoch 119/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 2001.2645 - mae: 37.2334 - mse: 2001.2645 - val_loss: 1740.4960 - val_mae: 34.0459 - val_mse: 1740.4960 - learning_rate: 3.9237e-04
# Epoch 120/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2004.0745 - mae: 37.2398 - mse: 2004.0745 - val_loss: 1778.1748 - val_mae: 34.5984 - val_mse: 1778.1748 - learning_rate: 3.9237e-04
# Epoch 121/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2003.7136 - mae: 37.2570 - mse: 2003.7136 - val_loss: 1835.6083 - val_mae: 35.3592 - val_mse: 1835.6083 - learning_rate: 3.6295e-04
# Epoch 122/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2002.4135 - mae: 37.2749 - mse: 2002.4135 - val_loss: 1923.4655 - val_mae: 36.4691 - val_mse: 1923.4655 - learning_rate: 3.6295e-04
# Epoch 123/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 2012.2957 - mae: 37.3817 - mse: 2012.2957 - val_loss: 1762.1665 - val_mae: 34.3727 - val_mse: 1762.1665 - learning_rate: 3.6295e-04
# Epoch 124/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 1995.8796 - mae: 37.2225 - mse: 1995.8796 - val_loss: 1763.6608 - val_mae: 34.3936 - val_mse: 1763.6608 - learning_rate: 3.6295e-04
# Epoch 125/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1998.2511 - mae: 37.2023 - mse: 1998.2511 - val_loss: 1742.6753 - val_mae: 34.0819 - val_mse: 1742.6753 - learning_rate: 3.6295e-04
# Epoch 126/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2013.4336 - mae: 37.3303 - mse: 2013.4336 - val_loss: 1729.4576 - val_mae: 33.8548 - val_mse: 1729.4576 - learning_rate: 3.6295e-04
# Epoch 127/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2009.8263 - mae: 37.3372 - mse: 2009.8263 - val_loss: 1736.2479 - val_mae: 33.9781 - val_mse: 1736.2479 - learning_rate: 3.6295e-04
# Epoch 128/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2004.1383 - mae: 37.2095 - mse: 2004.1383 - val_loss: 1819.4589 - val_mae: 35.1552 - val_mse: 1819.4589 - learning_rate: 3.6295e-04
# Epoch 129/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2007.1078 - mae: 37.2961 - mse: 2007.1078 - val_loss: 1817.7933 - val_mae: 35.1336 - val_mse: 1817.7933 - learning_rate: 3.6295e-04
# Epoch 130/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2000.6929 - mae: 37.2576 - mse: 2000.6929 - val_loss: 1745.3125 - val_mae: 34.1235 - val_mse: 1745.3125 - learning_rate: 3.6295e-04
# Epoch 131/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 1999.3176 - mae: 37.2618 - mse: 1999.3176 - val_loss: 1772.3440 - val_mae: 34.5192 - val_mse: 1772.3440 - learning_rate: 3.3573e-04
# Epoch 132/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 2009.3624 - mae: 37.3233 - mse: 2009.3624 - val_loss: 1737.8539 - val_mae: 34.0045 - val_mse: 1737.8539 - learning_rate: 3.3573e-04
# Epoch 133/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2001.1838 - mae: 37.2327 - mse: 2001.1838 - val_loss: 1755.5530 - val_mae: 34.2775 - val_mse: 1755.5530 - learning_rate: 3.3573e-04
# Epoch 134/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 2011.8762 - mae: 37.3861 - mse: 2011.8762 - val_loss: 1783.7410 - val_mae: 34.6786 - val_mse: 1783.7410 - learning_rate: 3.3573e-04
# Epoch 135/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 2015.7098 - mae: 37.3244 - mse: 2015.7098 - val_loss: 1826.4894 - val_mae: 35.2447 - val_mse: 1826.4894 - learning_rate: 3.3573e-04
# Epoch 136/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 2000.7622 - mae: 37.2255 - mse: 2000.7622 - val_loss: 1815.0364 - val_mae: 35.0974 - val_mse: 1815.0364 - learning_rate: 3.3573e-04
# Epoch 137/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 2008.3075 - mae: 37.3209 - mse: 2008.3075 - val_loss: 1741.5802 - val_mae: 34.0640 - val_mse: 1741.5802 - learning_rate: 3.3573e-04
# Epoch 138/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 2010.1875 - mae: 37.2554 - mse: 2010.1875 - val_loss: 1811.2345 - val_mae: 35.0479 - val_mse: 1811.2345 - learning_rate: 3.3573e-04
# Epoch 139/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 2014.5225 - mae: 37.4240 - mse: 2014.5225 - val_loss: 1793.6206 - val_mae: 34.8130 - val_mse: 1793.6206 - learning_rate: 3.3573e-04
# Epoch 140/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - loss: 1999.1326 - mae: 37.2281 - mse: 1999.1326 - val_loss: 1797.3906 - val_mae: 34.8648 - val_mse: 1797.3906 - learning_rate: 3.3573e-04
# Epoch 141/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - loss: 2004.8628 - mae: 37.2931 - mse: 2004.8628 - val_loss: 1812.9366 - val_mae: 35.0694 - val_mse: 1812.9366 - learning_rate: 3.1055e-04
# Epoch 142/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 98ms/step - loss: 2001.2860 - mae: 37.2211 - mse: 2001.2860 - val_loss: 1849.2656 - val_mae: 35.5353 - val_mse: 1849.2656 - learning_rate: 3.1055e-04
# Epoch 143/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 96ms/step - loss: 2013.0679 - mae: 37.3243 - mse: 2013.0679 - val_loss: 1744.6218 - val_mae: 34.1128 - val_mse: 1744.6218 - learning_rate: 3.1055e-04
# Epoch 144/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2004.6326 - mae: 37.2710 - mse: 2004.6326 - val_loss: 1718.3081 - val_mae: 33.5738 - val_mse: 1718.3081 - learning_rate: 3.1055e-04
# Epoch 145/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2009.4204 - mae: 37.3628 - mse: 2009.4204 - val_loss: 1770.0226 - val_mae: 34.4867 - val_mse: 1770.0226 - learning_rate: 3.1055e-04
# Epoch 146/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2011.4626 - mae: 37.4044 - mse: 2011.4626 - val_loss: 1742.6647 - val_mae: 34.0818 - val_mse: 1742.6647 - learning_rate: 3.1055e-04
# Epoch 147/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2001.5636 - mae: 37.2461 - mse: 2001.5636 - val_loss: 1750.4677 - val_mae: 34.1993 - val_mse: 1750.4677 - learning_rate: 3.1055e-04
# Epoch 148/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 2002.7579 - mae: 37.2881 - mse: 2002.7579 - val_loss: 1749.8470 - val_mae: 33.5636 - val_mse: 1749.8470 - learning_rate: 3.1055e-04
# Epoch 149/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 2028.7263 - mae: 37.4294 - mse: 2028.7263 - val_loss: 1758.6946 - val_mae: 34.3237 - val_mse: 1758.6946 - learning_rate: 3.1055e-04
# Epoch 150/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2005.9202 - mae: 37.2778 - mse: 2005.9202 - val_loss: 1746.0558 - val_mae: 34.1349 - val_mse: 1746.0558 - learning_rate: 3.1055e-04
# Epoch 151/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 2008.7136 - mae: 37.3914 - mse: 2008.7136 - val_loss: 1738.9705 - val_mae: 34.0223 - val_mse: 1738.9705 - learning_rate: 2.8726e-04
# Epoch 152/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 2000.4076 - mae: 37.2084 - mse: 2000.4076 - val_loss: 1749.4338 - val_mae: 34.1847 - val_mse: 1749.4338 - learning_rate: 2.8726e-04
# Epoch 153/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1996.8262 - mae: 37.2038 - mse: 1996.8262 - val_loss: 1759.7537 - val_mae: 34.3388 - val_mse: 1759.7537 - learning_rate: 2.8726e-04
# Epoch 154/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 2009.2941 - mae: 37.3272 - mse: 2009.2941 - val_loss: 1775.1763 - val_mae: 34.5580 - val_mse: 1775.1763 - learning_rate: 2.8726e-04
# Epoch 155/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2005.6107 - mae: 37.3138 - mse: 2005.6107 - val_loss: 1761.5742 - val_mae: 34.3645 - val_mse: 1761.5742 - learning_rate: 2.8726e-04
# Epoch 156/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2000.1654 - mae: 37.2222 - mse: 2000.1654 - val_loss: 1780.0035 - val_mae: 34.6251 - val_mse: 1780.0035 - learning_rate: 2.8726e-04
# Epoch 157/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2001.9436 - mae: 37.2549 - mse: 2001.9436 - val_loss: 1731.5786 - val_mae: 33.8944 - val_mse: 1731.5786 - learning_rate: 2.8726e-04
# Epoch 158/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 1998.7622 - mae: 37.2380 - mse: 1998.7622 - val_loss: 1773.0360 - val_mae: 34.5288 - val_mse: 1773.0360 - learning_rate: 2.8726e-04
# Epoch 159/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2008.0883 - mae: 37.3489 - mse: 2008.0883 - val_loss: 1787.7255 - val_mae: 34.7339 - val_mse: 1787.7255 - learning_rate: 2.8726e-04
# Epoch 160/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - loss: 2000.3927 - mae: 37.2314 - mse: 2000.3927 - val_loss: 1802.6584 - val_mae: 34.9362 - val_mse: 1802.6584 - learning_rate: 2.8726e-04
# Epoch 161/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - loss: 2005.1819 - mae: 37.3258 - mse: 2005.1819 - val_loss: 1740.5363 - val_mae: 34.0466 - val_mse: 1740.5363 - learning_rate: 2.6571e-04
# Epoch 162/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 2011.4449 - mae: 37.3246 - mse: 2011.4449 - val_loss: 1807.3500 - val_mae: 34.9979 - val_mse: 1807.3500 - learning_rate: 2.6571e-04
# Epoch 163/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 2000.7523 - mae: 37.3156 - mse: 2000.7523 - val_loss: 1768.1818 - val_mae: 34.4603 - val_mse: 1768.1818 - learning_rate: 2.6571e-04
# Epoch 164/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 1999.9595 - mae: 37.2278 - mse: 1999.9595 - val_loss: 1794.7968 - val_mae: 34.8287 - val_mse: 1794.7968 - learning_rate: 2.6571e-04
# Epoch 165/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2011.9229 - mae: 37.4078 - mse: 2011.9229 - val_loss: 1737.1228 - val_mae: 33.9926 - val_mse: 1737.1228 - learning_rate: 2.6571e-04
# Epoch 166/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2008.2177 - mae: 37.3265 - mse: 2008.2177 - val_loss: 1773.1083 - val_mae: 34.5298 - val_mse: 1773.1083 - learning_rate: 2.6571e-04
# Epoch 167/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 1999.6151 - mae: 37.2321 - mse: 1999.6151 - val_loss: 1728.9186 - val_mae: 33.8442 - val_mse: 1728.9186 - learning_rate: 2.6571e-04
# Epoch 168/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2005.8085 - mae: 37.1935 - mse: 2005.8085 - val_loss: 1780.9430 - val_mae: 34.6387 - val_mse: 1780.9430 - learning_rate: 2.6571e-04
# Epoch 169/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 1996.5990 - mae: 37.1554 - mse: 1996.5990 - val_loss: 1881.9017 - val_mae: 35.9505 - val_mse: 1881.9017 - learning_rate: 2.6571e-04
# Epoch 170/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2003.2976 - mae: 37.3333 - mse: 2003.2976 - val_loss: 1742.4277 - val_mae: 34.0779 - val_mse: 1742.4277 - learning_rate: 2.6571e-04
# Epoch 171/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2004.1847 - mae: 37.2423 - mse: 2004.1847 - val_loss: 1822.4265 - val_mae: 35.1934 - val_mse: 1822.4265 - learning_rate: 2.4578e-04
# Epoch 172/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 1999.1809 - mae: 37.2077 - mse: 1999.1809 - val_loss: 1770.8500 - val_mae: 34.4983 - val_mse: 1770.8500 - learning_rate: 2.4578e-04
# Epoch 173/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 1999.3152 - mae: 37.2604 - mse: 1999.3152 - val_loss: 1740.8455 - val_mae: 34.0518 - val_mse: 1740.8455 - learning_rate: 2.4578e-04
# Epoch 174/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2003.5917 - mae: 37.2510 - mse: 2003.5917 - val_loss: 1781.4294 - val_mae: 34.6457 - val_mse: 1781.4294 - learning_rate: 2.4578e-04
# Epoch 175/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 97ms/step - loss: 1998.3760 - mae: 37.2462 - mse: 1998.3760 - val_loss: 1758.9865 - val_mae: 34.3279 - val_mse: 1758.9865 - learning_rate: 2.4578e-04
# Epoch 176/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 1998.4113 - mae: 37.2076 - mse: 1998.4113 - val_loss: 1734.3738 - val_mae: 33.9457 - val_mse: 1734.3738 - learning_rate: 2.4578e-04
# Epoch 177/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 2007.8716 - mae: 37.2583 - mse: 2007.8716 - val_loss: 1911.6638 - val_mae: 36.3233 - val_mse: 1911.6638 - learning_rate: 2.4578e-04
# Epoch 178/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1999.1655 - mae: 37.2267 - mse: 1999.1655 - val_loss: 1737.8933 - val_mae: 34.0052 - val_mse: 1737.8933 - learning_rate: 2.4578e-04
# Epoch 179/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 2002.3967 - mae: 37.1973 - mse: 2002.3967 - val_loss: 1877.9550 - val_mae: 35.9008 - val_mse: 1877.9550 - learning_rate: 2.4578e-04
# Epoch 180/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 2011.5409 - mae: 37.3908 - mse: 2011.5409 - val_loss: 1953.9967 - val_mae: 36.8368 - val_mse: 1953.9967 - learning_rate: 2.4578e-04
# Epoch 181/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 2000.5693 - mae: 37.2625 - mse: 2000.5693 - val_loss: 1843.8948 - val_mae: 35.4672 - val_mse: 1843.8948 - learning_rate: 2.2735e-04
# Epoch 182/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - loss: 2006.0526 - mae: 37.2641 - mse: 2006.0526 - val_loss: 1797.0038 - val_mae: 34.8594 - val_mse: 1797.0038 - learning_rate: 2.2735e-04
# Epoch 183/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2008.8021 - mae: 37.3313 - mse: 2008.8021 - val_loss: 1730.5000 - val_mae: 33.8747 - val_mse: 1730.5000 - learning_rate: 2.2735e-04
# Epoch 184/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 1998.0366 - mae: 37.2604 - mse: 1998.0366 - val_loss: 1764.5836 - val_mae: 34.4075 - val_mse: 1764.5836 - learning_rate: 2.2735e-04
# Epoch 185/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2000.6298 - mae: 37.2622 - mse: 2000.6298 - val_loss: 1751.1183 - val_mae: 34.2088 - val_mse: 1751.1183 - learning_rate: 2.2735e-04
# Epoch 186/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2000.5178 - mae: 37.2420 - mse: 2000.5178 - val_loss: 1828.8052 - val_mae: 35.2735 - val_mse: 1828.8052 - learning_rate: 2.2735e-04
# Epoch 187/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 2003.9967 - mae: 37.3204 - mse: 2003.9967 - val_loss: 1728.8143 - val_mae: 33.8421 - val_mse: 1728.8143 - learning_rate: 2.2735e-04
# Epoch 188/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 2023.4414 - mae: 37.2832 - mse: 2023.4414 - val_loss: 1815.5068 - val_mae: 35.1036 - val_mse: 1815.5068 - learning_rate: 2.2735e-04
# Epoch 189/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - loss: 2001.2936 - mae: 37.2949 - mse: 2001.2936 - val_loss: 1738.0801 - val_mae: 34.0082 - val_mse: 1738.0801 - learning_rate: 2.2735e-04
# Epoch 190/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 108ms/step - loss: 2014.4030 - mae: 37.2627 - mse: 2014.4030 - val_loss: 1734.5135 - val_mae: 33.9482 - val_mse: 1734.5135 - learning_rate: 2.2735e-04
# Epoch 191/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - loss: 2004.2972 - mae: 37.2542 - mse: 2004.2972 - val_loss: 1729.4662 - val_mae: 33.8550 - val_mse: 1729.4662 - learning_rate: 2.1030e-04
# Epoch 192/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - loss: 1994.5236 - mae: 37.1713 - mse: 1994.5236 - val_loss: 1836.4485 - val_mae: 35.3704 - val_mse: 1836.4485 - learning_rate: 2.1030e-04
# Epoch 193/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - loss: 2010.6301 - mae: 37.4015 - mse: 2010.6301 - val_loss: 1906.6511 - val_mae: 36.2602 - val_mse: 1906.6511 - learning_rate: 2.1030e-04
# Epoch 194/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 2006.4736 - mae: 37.3825 - mse: 2006.4736 - val_loss: 1739.0656 - val_mae: 34.0238 - val_mse: 1739.0656 - learning_rate: 2.1030e-04
# Epoch 195/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 2005.7311 - mae: 37.1894 - mse: 2005.7311 - val_loss: 1785.4622 - val_mae: 34.7027 - val_mse: 1785.4622 - learning_rate: 2.1030e-04
# Epoch 196/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1997.6669 - mae: 37.2009 - mse: 1997.6669 - val_loss: 1743.0974 - val_mae: 34.0887 - val_mse: 1743.0974 - learning_rate: 2.1030e-04
# Epoch 197/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1996.9491 - mae: 37.2141 - mse: 1996.9491 - val_loss: 1832.9401 - val_mae: 35.3243 - val_mse: 1832.9401 - learning_rate: 2.1030e-04
# Epoch 198/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 2008.3088 - mae: 37.3632 - mse: 2008.3088 - val_loss: 1785.7042 - val_mae: 34.7061 - val_mse: 1785.7042 - learning_rate: 2.1030e-04
# Epoch 199/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2005.9199 - mae: 37.3759 - mse: 2005.9199 - val_loss: 1754.7802 - val_mae: 34.2658 - val_mse: 1754.7802 - learning_rate: 2.1030e-04
# Epoch 200/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 1997.5549 - mae: 37.2483 - mse: 1997.5549 - val_loss: 1722.5934 - val_mae: 33.7054 - val_mse: 1722.5934 - learning_rate: 2.1030e-04

# %%
output = model.evaluate(X_test, y_test, verbose=1)
print(output)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1474.5464 - mae: 30.4999 - mse: 1474.5464
# [1474.54638671875, 30.499916076660156, 1474.54638671875]

# %%
y_pred = model.predict(X_test)
y_true = y_test
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Plot predictions vs actual - now dates align correctly
plt.figure(figsize=(15, 8))

# Plot first 100 test samples
n_samples = min(100, len(y_test))
dates_plot = dates_test.iloc[:n_samples]
y_true_plot = y_true[:n_samples]
y_pred_plot = y_pred[:n_samples]

plt.subplot(2, 1, 1)
plt.plot(dates_plot, y_true_plot, label='True', marker='o', alpha=0.7, markersize=4)
plt.plot(dates_plot, y_pred_plot, label='Predicted', marker='x', alpha=0.7, markersize=4)
plt.title('First 100 Test Samples - Chronological Order')
plt.xlabel('Date')
plt.ylabel('Passenger Count')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
# Out:
# (array([20198.5, 20199. , 20199.5, 20200. , 20200.5, 20201. , 20201.5,
#         20202. , 20202.5]),
#  [Text(20198.5, 0, '04-20 12'),
#   Text(20199.0, 0, '04-21 00'),
#   Text(20199.5, 0, '04-21 12'),
#   Text(20200.0, 0, '04-22 00'),
#   Text(20200.5, 0, '04-22 12'),
#   Text(20201.0, 0, '04-23 00'),
#   Text(20201.5, 0, '04-23 12'),
#   Text(20202.0, 0, '04-24 00'),
#   Text(20202.5, 0, '04-24 12')])
