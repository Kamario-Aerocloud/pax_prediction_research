# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets/augmented_SRQ_data_v3.csv')
df[['Month', 'month_sin', 'month_cos']]
# Out:
#        Month     month_sin  month_cos
# 0          9 -8.660254e-01       -0.5
# 1          9 -8.660254e-01       -0.5
# 2          9 -8.660254e-01       -0.5
# 3          9 -8.660254e-01       -0.5
# 4          9 -8.660254e-01       -0.5
# ...      ...           ...        ...
# 12555      7  1.224647e-16       -1.0
# 12556      7  1.224647e-16       -1.0
# 12557      7  1.224647e-16       -1.0
# 12558      7  1.224647e-16       -1.0
# 12559      7  1.224647e-16       -1.0
#
# [12560 rows x 3 columns]

# %%
feature_columns = [  'Destination Airport_encoded', 'Airline_encoded',
    'Day_of_Week', 'Month', 'Day_of_Month', 
    'day_sin',  'month_sin', 'dow_sin',
    'day_cos', 'month_cos', 'dow_cos', 
    'route_mean', 'route_median', 'route_std',]

# %%
for col in feature_columns:
    if df[col].dtype != 'object':  # Only plot numeric columns
        plt.figure(figsize=(6, 4))
        plt.hist(df[col].dropna(), bins=30, edgecolor='black')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.grid(True)
        plt.show()
